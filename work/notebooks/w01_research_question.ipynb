# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulRaheem2004/ML_Week1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AbdulRaheem2004/ML_Week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# # My Lane
#
# **Lane:** Content Refresh Prioritization
#
# I chose this lane because it focuses on identifying webpages that are losing search performance and should be refreshed. Machine learning can help prioritize these pages using data instead of relying only on manual rules.

# %%
import os
print(os.getcwd())
print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# /content/ML_Week1
# True

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# # Research Question
#
# **Research Question:** Which webpages are most likely to experience declining search performance and should be prioritized for content refresh?
#
# **Decision:** Decide which pages should be refreshed first.
#
# **Action:** Update or improve the selected pages to recover search performance.
#
# **Cost of a Wrong Recommendation:** Refreshing the wrong pages wastes time and resources, while missing declining pages may result in further loss of search visibility.
#
# **Why ML?** Machine learning can analyze multiple page features together and identify useful patterns for prioritizing refresh decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !find . -name "content_refresh_anonymized.csv"
# Out:
# ./data/raw/content_refresh_anonymized.csv

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# # Quick Look at the Data
#
# The starter dataset contains **30,000 pages**. Around **54.2%** of the pages are labeled as declining. The correlation between **search_volume** and **impressions_90d** is **0.001**, showing that search volume alone is not a strong predictor of search visibility. These observations support studying content refresh prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Number of pages: {len(df)}")
print(f"Declining rate: {(df['trend_direction'].str.lower()=='down').mean():.3f}")
print(f"Correlation (search_volume vs impressions_90d): {df['search_volume'].corr(df['impressions_90d']):.3f}")
# Out:
# Number of pages: 30000
# Declining rate: 0.542
# Correlation (search_volume vs impressions_90d): 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# # Careful Words
#
# This project provides decision support by identifying patterns in the available data. The findings are observational and should not be interpreted as proof of how Google's ranking algorithm works or as guarantees of future search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
